# %%
import numpy as np
arr = np.array([1,8,2,5,0,2,4,7,2])

# %%
#tutorial punto 1

print('My array is:',arr)
# Out:
# My array is: [1 8 2 5 0 2 4 7 2]

# %%
#punto b

sorted_arr = np.sort(arr)
print(sorted_arr)
# Out:
# [0 1 2 2 2 4 5 7 8]

# %%
#punto c

total = sum(arr)
print(total)
# Out:
# 31

# %%
#punto d
#hay otra manera y es la suma dividido por el len tambien obtienes lo mismo
average = np.mean(arr)
print(average)
# Out:
# 3.4444444444444446

# %%
averaa= sum(arr) / len(arr)
print(averaa)
# Out:
# 3.4444444444444446

# %%
#punto e

minimum = min(arr)
maximum = max(arr)
print(minimum)
print(maximum)
# Out:
# 0
# 8

# %%
import matplotlib.pyplot as plt

max_temp = [32,30,31,28,29,25,22,18,19,22,25,28] 
min_temp = [28,26,25,23,24,20,18,13,14,16,18,22] 
months_ =  ['Jan','Feb','Mar','Apr','May','Ju','Jul','Aug','Sep','Oct','Nov','Dec']

plt.plot(months_, max_temp, color='blue')
plt.plot(months_, min_temp, color='orange') 
plt.title('Temperature of Year')
plt.xlabel('months_')
plt.ylabel('temperature')

plt.show()

# %%
#Aca queremos anadir leyend entonces hacemos esto 

plt.plot(months_, max_temp, label='max_temp',  color='blue')
plt.plot(months_, min_temp, label='min_temp', color='orange') 
plt.title('Temperature of Year')
plt.xlabel('months_')
plt.ylabel('temperature')
plt.legend(loc='lower left')

plt.show()

# %%
#Write a Python function that takes some string

def write_sentence_to_file(text):
    f= open('Angie.txt', 'w')
    f.write(text)
    f.close()
    
    
text= "“I need to write THIS sentence to a TEXT file using PYTHON"
write_sentence_to_file(text)

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 4220-7A88
#
#  Directory of C:\Users\AngieLorenaCEPEDAGAR\Documents\Programm
#
# 30/04/2025  03:46 PM    <DIR>          .
# 02/04/2025  02:14 PM    <DIR>          ..
# 30/04/2025  03:14 PM    <DIR>          .ipynb_checkpoints
# 30/04/2025  03:45 PM                58 Angie.txt
# 30/04/2025  03:12 PM               589 Untitled.ipynb
# 02/04/2025  03:26 PM            27,161 Week4.ipynb
# 09/04/2025  04:26 PM             9,649 Week5.ipynb
# 30/04/2025  03:46 PM           103,441 Week6.ipynb
#                5 File(s)        140,898 bytes
#                3 Dir(s)  361,984,253,952 bytes free

# %%
# Write a Python function that reads the content of a file created in Question 3 and finds  all the upper-case words

def read_sentence_to_file(file):
    f = open(file,'r')
    for line in f:
        print(line)
    
 
    
read_sentence_to_file('Angie.txt')
# Out:
# “I need to write THIS sentence to a TEXT file using PYTHON

# %%
#ahora con each word upper case 

def read_sentence_to_file(file):
    f = open(file,'r')
    for line in f:
        for word in line.split():
            if word.isupper():
                print(word)
       
    
read_sentence_to_file('Angie.txt')
# Out:
# “I
# THIS
# TEXT
# PYTHON

# %%
#ahora add these uppercase words to a list and print

def read_sentence_to_file(file):
    upper_list = []
    f = open(file,'r')
    for line in f:
        for word in line.split():
            if word.isupper():
                #print(word)
                upper_list.append(word)
    print(upper_list)

    
    
read_sentence_to_file('Angie.txt')
# Out:
# ['“I', 'THIS', 'TEXT', 'PYTHON']

# %% [markdown]
# CLASSES

# %%
#definiendo clase y adicionando el method Display

class Pet:
    def __init__(self, n, g):
        self.name = n
        self.gender = g
    def display(self):
        print("Name is =", self.name)
        print("Gender is=", self.gender)
        
dog = Pet("joy", "Male")
dog.display()
# Out:
# Name is = joy
# Gender is= Male

# %%
cat = Pet("Andy", "Female")
cat.display()
# Out:
# Name is = Andy
# Gender is= Female

# %%
#creando otra clase

class Order:
    def __init__(self, pr, p):
        self.product_amount = pr
        self.price = p
    def calculate_bill(self):
        return (self.product_amount*self.price)
    
milk = Order(5,2)
total_milk = milk.calculate_bill()
print(total_milk)
# Out:
# 10

# %%
#creando otro objeto

class Order:
    def __init__(self, pr, p):
        self.product_amount = pr
        self.price = p
    def calculate_bill(self):
        return (self.product_amount*self.price)
    
milk = Order(5,2)
total_milk = milk.calculate_bill()
print('Total of Milk', total_milk)

bread = Order(7,1)
total_bread = bread.calculate_bill()
print('Total of Bread', total_bread)

total_bill = total_milk + total_bread
print('Your total bill is',total_bill)
# Out:
# Total of Milk 10
# Total of Bread 7
# Your total bill is 17
